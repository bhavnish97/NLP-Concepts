# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=1c3b025be6058d7478ba283d5f8cd66636967c2d6862cff61d44257db5e93311
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv['Player']
# Out:
# array([ 0.03125   ,  0.01171875,  0.0255127 , -0.18066406,  0.40039062,
#        -0.11035156,  0.19628906,  0.3359375 ,  0.421875  ,  0.00227356,
#        -0.30859375,  0.22851562, -0.01489258, -0.23046875,  0.48828125,
#         0.35742188,  0.32421875, -0.08203125, -0.12255859, -0.21582031,
#         0.06396484,  0.11035156, -0.32226562, -0.10009766,  0.25585938,
#        -0.23046875, -0.22851562,  0.12695312,  0.328125  , -0.01965332,
#        -0.13378906, -0.08642578, -0.00878906, -0.40039062, -0.07714844,
#        -0.35742188, -0.05761719, -0.125     , -0.37890625,  0.6640625 ,
#         0.41796875, -0.10791016,  0.05200195,  0.03100586,  0.17480469,
#        -0.19726562,  0.36132812,  0.00494385,  0.1953125 ,  0.28125   ,
#        -0.5078125 ,  0.28710938,  0.38085938, -0.00735474, -0.06494141,
#        -0.04956055,  0.2109375 , -0.10839844,  0.06494141, -0.39648438,
#        -0.47070312,  0.08300781, -0.13476562, -0.07275391,  0.11035156,
# ...

# %%
wv.most_similar('Player')
# Out:
# [('Defensive_Player', 0.691960334777832),
#  ('Offensive_Player', 0.676175594329834),
#  ('Most_Valuable_Player', 0.6646947264671326),
#  ('Preseason_Player', 0.6446603536605835),
#  ('Rookie', 0.6320910453796387),
#  ('Athlete', 0.6235944032669067),
#  ('Volleyball_Player', 0.6215616464614868),
#  ('Male_Athlete', 0.6027706861495972),
#  ('Indoor_Track_Athlete', 0.6022752523422241),
#  ('Male_Student_Athlete', 0.6017658114433289)]

# %%
wv.most_similar('Burger')
# Out:
# [('Burgers', 0.620613694190979),
#  ('burger', 0.6195944547653198),
#  ('Stormers_flanker_Schalk', 0.6108964085578918),
#  ('Fries', 0.5838479995727539),
#  ('burgers', 0.5723941326141357),
#  ('Hamburger', 0.5668190717697144),
#  ('Springboks_flanker_Schalk', 0.5544619560241699),
#  ('Steak', 0.5451010465621948),
#  ('Burrito', 0.5393165349960327),
#  ('gourmet_burger', 0.5386834144592285)]

# %%
wv.most_similar('KFC')
# Out:
# [('Kentucky_Fried_Chicken', 0.7834806442260742),
#  ('Burger_King', 0.6728719472885132),
#  ('Pizza_Hut', 0.62290358543396),
#  ('Taco_Bell', 0.6114382743835449),
#  ('McDonalds', 0.5953150987625122),
#  ('Fiery_Grilled_Wings', 0.5909678936004639),
#  ('McDonald', 0.5810736417770386),
#  ('KFCs', 0.5750032067298889),
#  ('Subway', 0.5691156387329102),
#  ('spokeswoman_Laurie_Schalow', 0.5676469802856445)]
