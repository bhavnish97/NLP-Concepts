# %%
import pandas as pd
import requests

# %%
# get API key by login on TMDB site
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key={APIKEY}&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 97.37,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 17126},
#   {'adult': False,
#    'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 97.37,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 17126},
#  {'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
movies_data = pd.DataFrame(response.json()['results'])

# %%
movies_data
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 1   False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg          [18, 80]     278
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg   [35, 18, 10749]   19404
# 5   False  /rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg       [10749, 18]  851644
# 6   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg   [16, 10751, 14]     129
# 7   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 8   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 9   False  /3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg       [10749, 16]  372754
# 10  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg      [35, 53, 18]  496243
# 11  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# ...

# %%
top_movies = movies_data[['id', 'title', 'overview', 'release_date', 'adult', 'popularity', 'vote_average', 'vote_count']]

# %%
top_movies
# Out:
#         id                           title  \
# 0      238                   The Godfather
# 1      278        The Shawshank Redemption
# 2      240           The Godfather Part II
# 3      424                Schindler's List
# 4    19404     Dilwale Dulhania Le Jayenge
# 5   851644               20th Century Girl
# 6      129                   Spirited Away
# 7      389                    12 Angry Men
# 8   372058                      Your Name.
# 9   372754        Dou kyu sei – Classmates
# 10  496243                        Parasite
# 11     497                  The Green Mile
# 12     155                 The Dark Knight
# 13  696374               Gabriel's Inferno
# 14     680                    Pulp Fiction
# 15  724089      Gabriel's Inferno: Part II
# 16     429  The Good, the Bad and the Ugly
# 17  667257               Impossible Things
# 18  555604  Guillermo del Toro's Pinocchio
# 19      13                    Forrest Gump
#
# ...

# %%
all_movies = pd.DataFrame()

# %%
for i in range(1,500):
  requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=17bd2d67dc3c42c0db9bf2a0c0d85dc6&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'adult', 'popularity', 'vote_average', 'vote_count']]
  all_movies = all_movies.append(temp_df, ignore_index=True)

# %%
all_movies
# Out:
#           id                           title  \
# 0        238                   The Godfather
# 1        278        The Shawshank Redemption
# 2        240           The Godfather Part II
# 3        424                Schindler's List
# 4      19404     Dilwale Dulhania Le Jayenge
# ...      ...                             ...
# 9975  724089      Gabriel's Inferno: Part II
# 9976     429  The Good, the Bad and the Ugly
# 9977  667257               Impossible Things
# 9978  555604  Guillermo del Toro's Pinocchio
# 9979      13                    Forrest Gump
#
#                                                overview release_date  adult  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14  False
# 1     Framed in the 1940s for the double murder of h...   1994-09-23  False
# 2     In the continuing saga of the Corleone crime f...   1974-12-20  False
# 3     The true story of how businessman Oskar Schind...   1993-12-15  False
# ...
